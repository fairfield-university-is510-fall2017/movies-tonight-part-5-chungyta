# %% [markdown]
# # Movies Tonight Part 4
# __Use `%%sql` magic to write the queries listed below.__

# %%
# standard imports for Pandas and %sql magic
import pandas as pd
# %load_ext sql

# initialize a database connection; may have to adjust username and password 
# %sql mysql+pymysql://root:mysql@localhost/MoviesTonight
# Out:
# /anaconda/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 'Connected: root@MoviesTonight'

# %% [markdown]
# **1. Write a select query that returns the MovieTitle, TheaterName, and Showtime for each movie showing.**
# The query should use `JOIN … ON` syntax as described in your textbook. Also, use aliases ( `… AS …` ) to make sure that column names match exactly what is asked for.

# %%
# %%sql
# SELECT Movies.Title As MoviesTitle, Theaters.Name As TheaterName, `Show`.Showtime As Showtime
# From Movies
# Join `Show` on (Movies.MID = Show.MoviesID)
# Join Theaters on (Show.TheatersID = Theaters.TID);
# Out:
# 131 rows affected.
# [('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 15600)),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 26400)),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 34800)),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 18600)),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 32400)),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 32700)),
#  ('Independence Day', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 25200)),
#  ('Associate, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 16800)),
#  ('Associate, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27000)),
#  ('D3: The Mighty Ducks', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 9000)),
#  ('Dear God', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 18900)),
#  ('Dear God', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27900)),
#  ('First Wives Club, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 19800)),
#  ('First Wives Club, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 28800)),
#  ('Ghost & The Darkness, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 18000)),
#  ('Ghost & The Darkness, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27600)),
#  ('High School High', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 14400)),
#  ('High School High', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 22500)),
#  ('High School High', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 30600)),
#  ('Larger Than Life', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 30000)),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 17100)),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 20700)),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27900)),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 31500)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 15300)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 17100)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 18900)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 25200)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27000)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 28800)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 35100)),
#  ('Sleepers', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27000)),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 18000)),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 21600)),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 26100)),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 29700)),
#  ("Stephen King's Thinner", 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 21600)),
#  ('Associate, The', 'General Cinema Rancho 6', datetime.timedelta(0, 18000)),
#  ('Associate, The', 'General Cinema Rancho 6', datetime.timedelta(0, 27000)),
#  ('Dear God', 'General Cinema Rancho 6', datetime.timedelta(0, 17100)),
#  ('Dear God', 'General Cinema Rancho 6', datetime.timedelta(0, 26100)),
#  ('First Wives Club, The', 'General Cinema Rancho 6', datetime.timedelta(0, 19800)),
#  ('First Wives Club, The', 'General Cinema Rancho 6', datetime.timedelta(0, 28800)),
#  ('Michael Collins', 'General Cinema Rancho 6', datetime.timedelta(0, 14400)),
#  ('Michael Collins', 'General Cinema Rancho 6', datetime.timedelta(0, 26100)),
#  ('Romeo & Juliet', 'General Cinema Rancho 6', datetime.timedelta(0, 18900)),
#  ('Romeo & Juliet', 'General Cinema Rancho 6', datetime.timedelta(0, 27900)),
#  ('Sleepers', 'General Cinema Rancho 6', datetime.timedelta(0, 25200)),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', datetime.timedelta(0, 36300)),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', datetime.timedelta(0, 18900)),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', datetime.timedelta(0, 27600)),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 16800)),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 25800)),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 34800)),
#  ('Fly Away Home', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 13800)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 24600)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33300)),
#  ('Independence Day', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 22200)),
#  ('Independence Day', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33000)),
#  ('Michael Collins', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 22800)),
#  ('Michael Collins', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33000)),
#  ('Nutty Professor, The', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 15900)),
#  ('Nutty Professor, The', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 29100)),
#  ('Phenomenon', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 22800)),
#  ('Phenomenon', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33300)),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 16200)),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 25200)),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 34200)),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 15000)),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 23400)),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 32400)),
#  ('Surviving Picasso', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 24000)),
#  ('Surviving Picasso', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33900)),
#  ('Very Brady Sequel, A', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 21600)),
#  ('D3: The Mighty Ducks', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 15300)),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 24000)),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 32400)),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 15600)),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 23400)),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 31200)),
#  ('Fly Away Home', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 17400)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 26400)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 35400)),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 16200)),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 25200)),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 34200)),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 15900)),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 24600)),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 33300)),
#  ('Sleepers', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 19800)),
#  ('Sleepers', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 30600)),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 16800)),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 26100)),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 34800)),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 15000)),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 24300)),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 33900)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 15600)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 19200)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 25200)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 28800)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 34800)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 17100)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 21000)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 26100)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 29400)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 34200)),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 15600)),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 25800)),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 34200)),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 18000)),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 25200)),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 32400)),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 16200)),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 25200)),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 35100)),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 19500)),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 27000)),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 34500)),
#  ('Dear God', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 18900)),
#  ('Dear God', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 33900)),
#  ('Ghost & The Darkness, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 26100)),
#  ('Larger Than Life', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 27000)),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 37200)),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 16200)),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 27600)),
#  ('Set It Off', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 36300)),
#  ('Set It Off', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 16800)),
#  ('Set It Off', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 26400)),
#  ('Sleepers', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 15600)),
#  ('Sleepers', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 34200))]

# %% [markdown]
# **2. Write a select query to display the MovieTitle, TheaterName, and Showtime for each show after 7pm.** You can start with a copy of the previous query and then add a `WHERE` clause.

# %%
# %%sql
# SELECT m.Title As MoviesTitle, t.Name As TheaterName, s.Showtime As Showtime
# From Movies m, Theaters t, `Show` s
# WHERE m.MID = s.MoviesID
# AND s.TheatersID= t.TID
# AND s.Showtime > "7:00:00";
# Out:
# 64 rows affected.
# [('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 26400)),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 34800)),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 32400)),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', datetime.timedelta(0, 32700)),
#  ('Associate, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27000)),
#  ('Dear God', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27900)),
#  ('First Wives Club, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 28800)),
#  ('Ghost & The Darkness, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27600)),
#  ('High School High', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 30600)),
#  ('Larger Than Life', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 30000)),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27900)),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 31500)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27000)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 28800)),
#  ('Ransom', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 35100)),
#  ('Sleepers', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 27000)),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 26100)),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', datetime.timedelta(0, 29700)),
#  ('Associate, The', 'General Cinema Rancho 6', datetime.timedelta(0, 27000)),
#  ('Dear God', 'General Cinema Rancho 6', datetime.timedelta(0, 26100)),
#  ('First Wives Club, The', 'General Cinema Rancho 6', datetime.timedelta(0, 28800)),
#  ('Michael Collins', 'General Cinema Rancho 6', datetime.timedelta(0, 26100)),
#  ('Romeo & Juliet', 'General Cinema Rancho 6', datetime.timedelta(0, 27900)),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', datetime.timedelta(0, 36300)),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', datetime.timedelta(0, 27600)),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 25800)),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 34800)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33300)),
#  ('Independence Day', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33000)),
#  ('Michael Collins', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33000)),
#  ('Nutty Professor, The', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 29100)),
#  ('Phenomenon', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33300)),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 34200)),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 32400)),
#  ('Surviving Picasso', 'SOCAL Canyon Crest Cinema', datetime.timedelta(0, 33900)),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 32400)),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 31200)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 26400)),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 35400)),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 34200)),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 33300)),
#  ('Sleepers', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 30600)),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 26100)),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', datetime.timedelta(0, 34800)),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 33900)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 28800)),
#  ('Ransom', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 34800)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 26100)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 29400)),
#  ('Space Jam', 'SOCAL Marketplace Cinema', datetime.timedelta(0, 34200)),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 25800)),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 34200)),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 32400)),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 35100)),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 27000)),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', datetime.timedelta(0, 34500)),
#  ('Dear God', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 33900)),
#  ('Ghost & The Darkness, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 26100)),
#  ('Larger Than Life', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 27000)),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 37200)),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 27600)),
#  ('Set It Off', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 36300)),
#  ('Set It Off', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 26400)),
#  ('Sleepers', 'United Artists Riverside Park Sierra', datetime.timedelta(0, 34200))]

# %% [markdown]
# **3. Write a select query to display the cast (actors only) of each movie.** The query should return the Movie Title, Actor Name, MID, and AID.

# %%
# %%sql
# Select m.Title, A.Name, A.Aid, m.MID
# From Artist A, Movies m;
# Out:
# 3496 rows affected.
# [('Associate, The', 'Austin Pendleton', 1, 1),
#  ('Ghost & The Darkness, The', 'Austin Pendleton', 1, 2),
#  ('Independence Day', 'Austin Pendleton', 1, 3),
#  ('D3: The Mighty Ducks', 'Austin Pendleton', 1, 4),
#  ('Dear God', 'Austin Pendleton', 1, 5),
#  ('First Wives Club, The', 'Austin Pendleton', 1, 6),
#  ('High School High', 'Austin Pendleton', 1, 7),
#  ('Larger Than Life', 'Austin Pendleton', 1, 8),
#  ('Mirror Has Two Faces, The', 'Austin Pendleton', 1, 9),
#  ('Ransom', 'Austin Pendleton', 1, 10),
#  ('Sleepers', 'Austin Pendleton', 1, 11),
#  ('Space Jam', 'Austin Pendleton', 1, 12),
#  ("Stephen King's Thinner", 'Austin Pendleton', 1, 13),
#  ('Michael Collins', 'Austin Pendleton', 1, 14),
#  ('Romeo & Juliet', 'Austin Pendleton', 1, 15),
#  ('Big Night', 'Austin Pendleton', 1, 16),
#  ('Fly Away Home', 'Austin Pendleton', 1, 17),
#  ('Nutty Professor, The', 'Austin Pendleton', 1, 18),
#  ('Phenomenon', 'Austin Pendleton', 1, 19),
#  ('Set It Off', 'Austin Pendleton', 1, 20),
#  ('Surviving Picasso', 'Austin Pendleton', 1, 21),
#  ('Very Brady Sequel, A', 'Austin Pendleton', 1, 22),
#  ('That Thing You Do', 'Austin Pendleton', 1, 23),
#  ('Associate, The', 'Bebe Neuwirth', 2, 1),
#  ('Ghost & The Darkness, The', 'Bebe Neuwirth', 2, 2),
#  ('Independence Day', 'Bebe Neuwirth', 2, 3),
#  ('D3: The Mighty Ducks', 'Bebe Neuwirth', 2, 4),
#  ('Dear God', 'Bebe Neuwirth', 2, 5),
#  ('First Wives Club, The', 'Bebe Neuwirth', 2, 6),
#  ('High School High', 'Bebe Neuwirth', 2, 7),
#  ('Larger Than Life', 'Bebe Neuwirth', 2, 8),
#  ('Mirror Has Two Faces, The', 'Bebe Neuwirth', 2, 9),
#  ('Ransom', 'Bebe Neuwirth', 2, 10),
#  ('Sleepers', 'Bebe Neuwirth', 2, 11),
#  ('Space Jam', 'Bebe Neuwirth', 2, 12),
#  ("Stephen King's Thinner", 'Bebe Neuwirth', 2, 13),
#  ('Michael Collins', 'Bebe Neuwirth', 2, 14),
#  ('Romeo & Juliet', 'Bebe Neuwirth', 2, 15),
#  ('Big Night', 'Bebe Neuwirth', 2, 16),
#  ('Fly Away Home', 'Bebe Neuwirth', 2, 17),
#  ('Nutty Professor, The', 'Bebe Neuwirth', 2, 18),
#  ('Phenomenon', 'Bebe Neuwirth', 2, 19),
#  ('Set It Off', 'Bebe Neuwirth', 2, 20),
#  ('Surviving Picasso', 'Bebe Neuwirth', 2, 21),
#  ('Very Brady Sequel, A', 'Bebe Neuwirth', 2, 22),
#  ('That Thing You Do', 'Bebe Neuwirth', 2, 23),
#  ('Associate, The', 'Dianne Wiest', 3, 1),
#  ('Ghost & The Darkness, The', 'Dianne Wiest', 3, 2),
#  ('Independence Day', 'Dianne Wiest', 3, 3),
#  ('D3: The Mighty Ducks', 'Dianne Wiest', 3, 4),
#  ('Dear God', 'Dianne Wiest', 3, 5),
#  ('First Wives Club, The', 'Dianne Wiest', 3, 6),
#  ('High School High', 'Dianne Wiest', 3, 7),
#  ('Larger Than Life', 'Dianne Wiest', 3, 8),
#  ('Mirror Has Two Faces, The', 'Dianne Wiest', 3, 9),
#  ('Ransom', 'Dianne Wiest', 3, 10),
#  ('Sleepers', 'Dianne Wiest', 3, 11),
#  ('Space Jam', 'Dianne Wiest', 3, 12),
#  ("Stephen King's Thinner", 'Dianne Wiest', 3, 13),
#  ('Michael Collins', 'Dianne Wiest', 3, 14),
#  ('Romeo & Juliet', 'Dianne Wiest', 3, 15),
#  ('Big Night', 'Dianne Wiest', 3, 16),
#  ('Fly Away Home', 'Dianne Wiest', 3, 17),
#  ('Nutty Professor, The', 'Dianne Wiest', 3, 18),
#  ('Phenomenon', 'Dianne Wiest', 3, 19),
#  ('Set It Off', 'Dianne Wiest', 3, 20),
#  ('Surviving Picasso', 'Dianne Wiest', 3, 21),
#  ('Very Brady Sequel, A', 'Dianne Wiest', 3, 22),
#  ('That Thing You Do', 'Dianne Wiest', 3, 23),
#  ('Associate, The', 'Eli Wallach', 4, 1),
#  ('Ghost & The Darkness, The', 'Eli Wallach', 4, 2),
#  ('Independence Day', 'Eli Wallach', 4, 3),
#  ('D3: The Mighty Ducks', 'Eli Wallach', 4, 4),
#  ('Dear God', 'Eli Wallach', 4, 5),
#  ('First Wives Club, The', 'Eli Wallach', 4, 6),
#  ('High School High', 'Eli Wallach', 4, 7),
#  ('Larger Than Life', 'Eli Wallach', 4, 8),
#  ('Mirror Has Two Faces, The', 'Eli Wallach', 4, 9),
#  ('Ransom', 'Eli Wallach', 4, 10),
#  ('Sleepers', 'Eli Wallach', 4, 11),
#  ('Space Jam', 'Eli Wallach', 4, 12),
#  ("Stephen King's Thinner", 'Eli Wallach', 4, 13),
#  ('Michael Collins', 'Eli Wallach', 4, 14),
#  ('Romeo & Juliet', 'Eli Wallach', 4, 15),
#  ('Big Night', 'Eli Wallach', 4, 16),
#  ('Fly Away Home', 'Eli Wallach', 4, 17),
#  ('Nutty Professor, The', 'Eli Wallach', 4, 18),
#  ('Phenomenon', 'Eli Wallach', 4, 19),
#  ('Set It Off', 'Eli Wallach', 4, 20),
#  ('Surviving Picasso', 'Eli Wallach', 4, 21),
#  ('Very Brady Sequel, A', 'Eli Wallach', 4, 22),
#  ('That Thing You Do', 'Eli Wallach', 4, 23),
#  ('Associate, The', 'Kenny Kerr', 5, 1),
#  ('Ghost & The Darkness, The', 'Kenny Kerr', 5, 2),
#  ('Independence Day', 'Kenny Kerr', 5, 3),
#  ('D3: The Mighty Ducks', 'Kenny Kerr', 5, 4),
#  ('Dear God', 'Kenny Kerr', 5, 5),
#  ('First Wives Club, The', 'Kenny Kerr', 5, 6),
#  ('High School High', 'Kenny Kerr', 5, 7),
#  ('Larger Than Life', 'Kenny Kerr', 5, 8),
#  ('Mirror Has Two Faces, The', 'Kenny Kerr', 5, 9),
#  ('Ransom', 'Kenny Kerr', 5, 10),
#  ('Sleepers', 'Kenny Kerr', 5, 11),
#  ('Space Jam', 'Kenny Kerr', 5, 12),
#  ("Stephen King's Thinner", 'Kenny Kerr', 5, 13),
#  ('Michael Collins', 'Kenny Kerr', 5, 14),
#  ('Romeo & Juliet', 'Kenny Kerr', 5, 15),
#  ('Big Night', 'Kenny Kerr', 5, 16),
#  ('Fly Away Home', 'Kenny Kerr', 5, 17),
#  ('Nutty Professor, The', 'Kenny Kerr', 5, 18),
#  ('Phenomenon', 'Kenny Kerr', 5, 19),
#  ('Set It Off', 'Kenny Kerr', 5, 20),
#  ('Surviving Picasso', 'Kenny Kerr', 5, 21),
#  ('Very Brady Sequel, A', 'Kenny Kerr', 5, 22),
#  ('That Thing You Do', 'Kenny Kerr', 5, 23),
#  ('Associate, The', 'Lainie Kazan', 6, 1),
#  ('Ghost & The Darkness, The', 'Lainie Kazan', 6, 2),
#  ('Independence Day', 'Lainie Kazan', 6, 3),
#  ('D3: The Mighty Ducks', 'Lainie Kazan', 6, 4),
#  ('Dear God', 'Lainie Kazan', 6, 5),
#  ('First Wives Club, The', 'Lainie Kazan', 6, 6),
#  ('High School High', 'Lainie Kazan', 6, 7),
#  ('Larger Than Life', 'Lainie Kazan', 6, 8),
#  ('Mirror Has Two Faces, The', 'Lainie Kazan', 6, 9),
#  ('Ransom', 'Lainie Kazan', 6, 10),
#  ('Sleepers', 'Lainie Kazan', 6, 11),
#  ('Space Jam', 'Lainie Kazan', 6, 12),
#  ("Stephen King's Thinner", 'Lainie Kazan', 6, 13),
#  ('Michael Collins', 'Lainie Kazan', 6, 14),
#  ('Romeo & Juliet', 'Lainie Kazan', 6, 15),
#  ('Big Night', 'Lainie Kazan', 6, 16),
#  ('Fly Away Home', 'Lainie Kazan', 6, 17),
#  ('Nutty Professor, The', 'Lainie Kazan', 6, 18),
#  ('Phenomenon', 'Lainie Kazan', 6, 19),
#  ('Set It Off', 'Lainie Kazan', 6, 20),
#  ('Surviving Picasso', 'Lainie Kazan', 6, 21),
#  ('Very Brady Sequel, A', 'Lainie Kazan', 6, 22),
#  ('That Thing You Do', 'Lainie Kazan', 6, 23),
#  ('Associate, The', 'Tim Daly', 7, 1),
#  ('Ghost & The Darkness, The', 'Tim Daly', 7, 2),
#  ('Independence Day', 'Tim Daly', 7, 3),
#  ('D3: The Mighty Ducks', 'Tim Daly', 7, 4),
#  ('Dear God', 'Tim Daly', 7, 5),
#  ('First Wives Club, The', 'Tim Daly', 7, 6),
#  ('High School High', 'Tim Daly', 7, 7),
#  ('Larger Than Life', 'Tim Daly', 7, 8),
#  ('Mirror Has Two Faces, The', 'Tim Daly', 7, 9),
#  ('Ransom', 'Tim Daly', 7, 10),
#  ('Sleepers', 'Tim Daly', 7, 11),
#  ('Space Jam', 'Tim Daly', 7, 12),
#  ("Stephen King's Thinner", 'Tim Daly', 7, 13),
#  ('Michael Collins', 'Tim Daly', 7, 14),
#  ('Romeo & Juliet', 'Tim Daly', 7, 15),
#  ('Big Night', 'Tim Daly', 7, 16),
#  ('Fly Away Home', 'Tim Daly', 7, 17),
#  ('Nutty Professor, The', 'Tim Daly', 7, 18),
#  ('Phenomenon', 'Tim Daly', 7, 19),
#  ('Set It Off', 'Tim Daly', 7, 20),
#  ('Surviving Picasso', 'Tim Daly', 7, 21),
#  ('Very Brady Sequel, A', 'Tim Daly', 7, 22),
#  ('That Thing You Do', 'Tim Daly', 7, 23),
#  ('Associate, The', 'Whoopi Goldberg', 8, 1),
#  ('Ghost & The Darkness, The', 'Whoopi Goldberg', 8, 2),
#  ('Independence Day', 'Whoopi Goldberg', 8, 3),
#  ('D3: The Mighty Ducks', 'Whoopi Goldberg', 8, 4),
#  ('Dear God', 'Whoopi Goldberg', 8, 5),
#  ('First Wives Club, The', 'Whoopi Goldberg', 8, 6),
#  ('High School High', 'Whoopi Goldberg', 8, 7),
#  ('Larger Than Life', 'Whoopi Goldberg', 8, 8),
#  ('Mirror Has Two Faces, The', 'Whoopi Goldberg', 8, 9),
#  ('Ransom', 'Whoopi Goldberg', 8, 10),
#  ('Sleepers', 'Whoopi Goldberg', 8, 11),
#  ('Space Jam', 'Whoopi Goldberg', 8, 12),
#  ("Stephen King's Thinner", 'Whoopi Goldberg', 8, 13),
#  ('Michael Collins', 'Whoopi Goldberg', 8, 14),
#  ('Romeo & Juliet', 'Whoopi Goldberg', 8, 15),
#  ('Big Night', 'Whoopi Goldberg', 8, 16),
#  ('Fly Away Home', 'Whoopi Goldberg', 8, 17),
#  ('Nutty Professor, The', 'Whoopi Goldberg', 8, 18),
#  ('Phenomenon', 'Whoopi Goldberg', 8, 19),
#  ('Set It Off', 'Whoopi Goldberg', 8, 20),
#  ('Surviving Picasso', 'Whoopi Goldberg', 8, 21),
#  ('Very Brady Sequel, A', 'Whoopi Goldberg', 8, 22),
#  ('That Thing You Do', 'Whoopi Goldberg', 8, 23),
#  ('Associate, The', 'Donald Petrie', 9, 1),
#  ('Ghost & The Darkness, The', 'Donald Petrie', 9, 2),
#  ('Independence Day', 'Donald Petrie', 9, 3),
#  ('D3: The Mighty Ducks', 'Donald Petrie', 9, 4),
#  ('Dear God', 'Donald Petrie', 9, 5),
#  ('First Wives Club, The', 'Donald Petrie', 9, 6),
#  ('High School High', 'Donald Petrie', 9, 7),
#  ('Larger Than Life', 'Donald Petrie', 9, 8),
#  ('Mirror Has Two Faces, The', 'Donald Petrie', 9, 9),
#  ('Ransom', 'Donald Petrie', 9, 10),
#  ('Sleepers', 'Donald Petrie', 9, 11),
#  ('Space Jam', 'Donald Petrie', 9, 12),
#  ("Stephen King's Thinner", 'Donald Petrie', 9, 13),
#  ('Michael Collins', 'Donald Petrie', 9, 14),
#  ('Romeo & Juliet', 'Donald Petrie', 9, 15),
#  ('Big Night', 'Donald Petrie', 9, 16),
#  ('Fly Away Home', 'Donald Petrie', 9, 17),
#  ('Nutty Professor, The', 'Donald Petrie', 9, 18),
#  ('Phenomenon', 'Donald Petrie', 9, 19),
#  ('Set It Off', 'Donald Petrie', 9, 20),
#  ('Surviving Picasso', 'Donald Petrie', 9, 21),
#  ('Very Brady Sequel, A', 'Donald Petrie', 9, 22),
#  ('That Thing You Do', 'Donald Petrie', 9, 23),
#  ('Associate, The', 'Bernard Hill', 10, 1),
#  ('Ghost & The Darkness, The', 'Bernard Hill', 10, 2),
#  ('Independence Day', 'Bernard Hill', 10, 3),
#  ('D3: The Mighty Ducks', 'Bernard Hill', 10, 4),
#  ('Dear God', 'Bernard Hill', 10, 5),
#  ('First Wives Club, The', 'Bernard Hill', 10, 6),
#  ('High School High', 'Bernard Hill', 10, 7),
#  ('Larger Than Life', 'Bernard Hill', 10, 8),
#  ('Mirror Has Two Faces, The', 'Bernard Hill', 10, 9),
#  ('Ransom', 'Bernard Hill', 10, 10),
#  ('Sleepers', 'Bernard Hill', 10, 11),
#  ('Space Jam', 'Bernard Hill', 10, 12),
#  ("Stephen King's Thinner", 'Bernard Hill', 10, 13),
#  ('Michael Collins', 'Bernard Hill', 10, 14),
#  ('Romeo & Juliet', 'Bernard Hill', 10, 15),
#  ('Big Night', 'Bernard Hill', 10, 16),
#  ('Fly Away Home', 'Bernard Hill', 10, 17),
#  ('Nutty Professor, The', 'Bernard Hill', 10, 18),
#  ('Phenomenon', 'Bernard Hill', 10, 19),
#  ('Set It Off', 'Bernard Hill', 10, 20),
#  ('Surviving Picasso', 'Bernard Hill', 10, 21),
#  ('Very Brady Sequel, A', 'Bernard Hill', 10, 22),
#  ('That Thing You Do', 'Bernard Hill', 10, 23),
#  ('Associate, The', 'Brian McCardie', 11, 1),
#  ('Ghost & The Darkness, The', 'Brian McCardie', 11, 2),
#  ('Independence Day', 'Brian McCardie', 11, 3),
#  ('D3: The Mighty Ducks', 'Brian McCardie', 11, 4),
#  ('Dear God', 'Brian McCardie', 11, 5),
#  ('First Wives Club, The', 'Brian McCardie', 11, 6),
#  ('High School High', 'Brian McCardie', 11, 7),
#  ('Larger Than Life', 'Brian McCardie', 11, 8),
#  ('Mirror Has Two Faces, The', 'Brian McCardie', 11, 9),
#  ('Ransom', 'Brian McCardie', 11, 10),
#  ('Sleepers', 'Brian McCardie', 11, 11),
#  ('Space Jam', 'Brian McCardie', 11, 12),
#  ("Stephen King's Thinner", 'Brian McCardie', 11, 13),
#  ('Michael Collins', 'Brian McCardie', 11, 14),
#  ('Romeo & Juliet', 'Brian McCardie', 11, 15),
#  ('Big Night', 'Brian McCardie', 11, 16),
#  ('Fly Away Home', 'Brian McCardie', 11, 17),
#  ('Nutty Professor, The', 'Brian McCardie', 11, 18),
#  ('Phenomenon', 'Brian McCardie', 11, 19),
#  ('Set It Off', 'Brian McCardie', 11, 20),
#  ('Surviving Picasso', 'Brian McCardie', 11, 21),
#  ('Very Brady Sequel, A', 'Brian McCardie', 11, 22),
#  ('That Thing You Do', 'Brian McCardie', 11, 23),
#  ('Associate, The', 'Emily Mortimer', 12, 1),
#  ('Ghost & The Darkness, The', 'Emily Mortimer', 12, 2),
#  ('Independence Day', 'Emily Mortimer', 12, 3),
#  ('D3: The Mighty Ducks', 'Emily Mortimer', 12, 4),
#  ('Dear God', 'Emily Mortimer', 12, 5),
#  ('First Wives Club, The', 'Emily Mortimer', 12, 6),
#  ('High School High', 'Emily Mortimer', 12, 7),
#  ('Larger Than Life', 'Emily Mortimer', 12, 8),
#  ('Mirror Has Two Faces, The', 'Emily Mortimer', 12, 9),
#  ('Ransom', 'Emily Mortimer', 12, 10),
#  ('Sleepers', 'Emily Mortimer', 12, 11),
#  ('Space Jam', 'Emily Mortimer', 12, 12),
#  ("Stephen King's Thinner", 'Emily Mortimer', 12, 13),
#  ('Michael Collins', 'Emily Mortimer', 12, 14),
#  ('Romeo & Juliet', 'Emily Mortimer', 12, 15),
#  ('Big Night', 'Emily Mortimer', 12, 16),
#  ('Fly Away Home', 'Emily Mortimer', 12, 17),
#  ('Nutty Professor, The', 'Emily Mortimer', 12, 18),
#  ('Phenomenon', 'Emily Mortimer', 12, 19),
#  ('Set It Off', 'Emily Mortimer', 12, 20),
#  ('Surviving Picasso', 'Emily Mortimer', 12, 21),
#  ('Very Brady Sequel, A', 'Emily Mortimer', 12, 22),
#  ('That Thing You Do', 'Emily Mortimer', 12, 23),
#  ('Associate, The', 'Henry Cele', 13, 1),
#  ('Ghost & The Darkness, The', 'Henry Cele', 13, 2),
#  ('Independence Day', 'Henry Cele', 13, 3),
#  ('D3: The Mighty Ducks', 'Henry Cele', 13, 4),
#  ('Dear God', 'Henry Cele', 13, 5),
#  ('First Wives Club, The', 'Henry Cele', 13, 6),
#  ('High School High', 'Henry Cele', 13, 7),
#  ('Larger Than Life', 'Henry Cele', 13, 8),
#  ('Mirror Has Two Faces, The', 'Henry Cele', 13, 9),
#  ('Ransom', 'Henry Cele', 13, 10),
#  ('Sleepers', 'Henry Cele', 13, 11),
#  ('Space Jam', 'Henry Cele', 13, 12),
#  ("Stephen King's Thinner", 'Henry Cele', 13, 13),
#  ('Michael Collins', 'Henry Cele', 13, 14),
#  ('Romeo & Juliet', 'Henry Cele', 13, 15),
#  ('Big Night', 'Henry Cele', 13, 16),
#  ('Fly Away Home', 'Henry Cele', 13, 17),
#  ('Nutty Professor, The', 'Henry Cele', 13, 18),
#  ('Phenomenon', 'Henry Cele', 13, 19),
#  ('Set It Off', 'Henry Cele', 13, 20),
#  ('Surviving Picasso', 'Henry Cele', 13, 21),
#  ('Very Brady Sequel, A', 'Henry Cele', 13, 22),
#  ('That Thing You Do', 'Henry Cele', 13, 23),
#  ('Associate, The', 'John Kani', 14, 1),
#  ('Ghost & The Darkness, The', 'John Kani', 14, 2),
#  ('Independence Day', 'John Kani', 14, 3),
#  ('D3: The Mighty Ducks', 'John Kani', 14, 4),
#  ('Dear God', 'John Kani', 14, 5),
#  ('First Wives Club, The', 'John Kani', 14, 6),
#  ('High School High', 'John Kani', 14, 7),
#  ('Larger Than Life', 'John Kani', 14, 8),
#  ('Mirror Has Two Faces, The', 'John Kani', 14, 9),
#  ('Ransom', 'John Kani', 14, 10),
#  ('Sleepers', 'John Kani', 14, 11),
#  ('Space Jam', 'John Kani', 14, 12),
#  ("Stephen King's Thinner", 'John Kani', 14, 13),
#  ('Michael Collins', 'John Kani', 14, 14),
#  ('Romeo & Juliet', 'John Kani', 14, 15),
#  ('Big Night', 'John Kani', 14, 16),
#  ('Fly Away Home', 'John Kani', 14, 17),
#  ('Nutty Professor, The', 'John Kani', 14, 18),
#  ('Phenomenon', 'John Kani', 14, 19),
#  ('Set It Off', 'John Kani', 14, 20),
#  ('Surviving Picasso', 'John Kani', 14, 21),
#  ('Very Brady Sequel, A', 'John Kani', 14, 22),
#  ('That Thing You Do', 'John Kani', 14, 23),
#  ('Associate, The', 'Michael Douglas', 15, 1),
#  ('Ghost & The Darkness, The', 'Michael Douglas', 15, 2),
#  ('Independence Day', 'Michael Douglas', 15, 3),
#  ('D3: The Mighty Ducks', 'Michael Douglas', 15, 4),
#  ('Dear God', 'Michael Douglas', 15, 5),
#  ('First Wives Club, The', 'Michael Douglas', 15, 6),
#  ('High School High', 'Michael Douglas', 15, 7),
#  ('Larger Than Life', 'Michael Douglas', 15, 8),
#  ('Mirror Has Two Faces, The', 'Michael Douglas', 15, 9),
#  ('Ransom', 'Michael Douglas', 15, 10),
#  ('Sleepers', 'Michael Douglas', 15, 11),
#  ('Space Jam', 'Michael Douglas', 15, 12),
#  ("Stephen King's Thinner", 'Michael Douglas', 15, 13),
#  ('Michael Collins', 'Michael Douglas', 15, 14),
#  ('Romeo & Juliet', 'Michael Douglas', 15, 15),
#  ('Big Night', 'Michael Douglas', 15, 16),
#  ('Fly Away Home', 'Michael Douglas', 15, 17),
#  ('Nutty Professor, The', 'Michael Douglas', 15, 18),
#  ('Phenomenon', 'Michael Douglas', 15, 19),
#  ('Set It Off', 'Michael Douglas', 15, 20),
#  ('Surviving Picasso', 'Michael Douglas', 15, 21),
#  ('Very Brady Sequel, A', 'Michael Douglas', 15, 22),
#  ('That Thing You Do', 'Michael Douglas', 15, 23),
#  ('Associate, The', 'Tom Wilkinson', 16, 1),
#  ('Ghost & The Darkness, The', 'Tom Wilkinson', 16, 2),
#  ('Independence Day', 'Tom Wilkinson', 16, 3),
#  ('D3: The Mighty Ducks', 'Tom Wilkinson', 16, 4),
#  ('Dear God', 'Tom Wilkinson', 16, 5),
#  ('First Wives Club, The', 'Tom Wilkinson', 16, 6),
#  ('High School High', 'Tom Wilkinson', 16, 7),
#  ('Larger Than Life', 'Tom Wilkinson', 16, 8),
#  ('Mirror Has Two Faces, The', 'Tom Wilkinson', 16, 9),
#  ('Ransom', 'Tom Wilkinson', 16, 10),
#  ('Sleepers', 'Tom Wilkinson', 16, 11),
#  ('Space Jam', 'Tom Wilkinson', 16, 12),
#  ("Stephen King's Thinner", 'Tom Wilkinson', 16, 13),
#  ('Michael Collins', 'Tom Wilkinson', 16, 14),
#  ('Romeo & Juliet', 'Tom Wilkinson', 16, 15),
#  ('Big Night', 'Tom Wilkinson', 16, 16),
#  ('Fly Away Home', 'Tom Wilkinson', 16, 17),
#  ('Nutty Professor, The', 'Tom Wilkinson', 16, 18),
#  ('Phenomenon', 'Tom Wilkinson', 16, 19),
#  ('Set It Off', 'Tom Wilkinson', 16, 20),
#  ('Surviving Picasso', 'Tom Wilkinson', 16, 21),
#  ('Very Brady Sequel, A', 'Tom Wilkinson', 16, 22),
#  ('That Thing You Do', 'Tom Wilkinson', 16, 23),
#  ('Associate, The', 'Val Kilmer', 17, 1),
#  ('Ghost & The Darkness, The', 'Val Kilmer', 17, 2),
#  ('Independence Day', 'Val Kilmer', 17, 3),
#  ('D3: The Mighty Ducks', 'Val Kilmer', 17, 4),
#  ('Dear God', 'Val Kilmer', 17, 5),
#  ('First Wives Club, The', 'Val Kilmer', 17, 6),
#  ('High School High', 'Val Kilmer', 17, 7),
#  ('Larger Than Life', 'Val Kilmer', 17, 8),
#  ('Mirror Has Two Faces, The', 'Val Kilmer', 17, 9),
#  ('Ransom', 'Val Kilmer', 17, 10),
#  ('Sleepers', 'Val Kilmer', 17, 11),
#  ('Space Jam', 'Val Kilmer', 17, 12),
#  ("Stephen King's Thinner", 'Val Kilmer', 17, 13),
#  ('Michael Collins', 'Val Kilmer', 17, 14),
#  ('Romeo & Juliet', 'Val Kilmer', 17, 15),
#  ('Big Night', 'Val Kilmer', 17, 16),
#  ('Fly Away Home', 'Val Kilmer', 17, 17),
#  ('Nutty Professor, The', 'Val Kilmer', 17, 18),
#  ('Phenomenon', 'Val Kilmer', 17, 19),
#  ('Set It Off', 'Val Kilmer', 17, 20),
#  ('Surviving Picasso', 'Val Kilmer', 17, 21),
#  ('Very Brady Sequel, A', 'Val Kilmer', 17, 22),
#  ('That Thing You Do', 'Val Kilmer', 17, 23),
#  ('Associate, The', 'Stephen Hopkins', 18, 1),
#  ('Ghost & The Darkness, The', 'Stephen Hopkins', 18, 2),
#  ('Independence Day', 'Stephen Hopkins', 18, 3),
#  ('D3: The Mighty Ducks', 'Stephen Hopkins', 18, 4),
#  ('Dear God', 'Stephen Hopkins', 18, 5),
#  ('First Wives Club, The', 'Stephen Hopkins', 18, 6),
#  ('High School High', 'Stephen Hopkins', 18, 7),
#  ('Larger Than Life', 'Stephen Hopkins', 18, 8),
#  ('Mirror Has Two Faces, The', 'Stephen Hopkins', 18, 9),
#  ('Ransom', 'Stephen Hopkins', 18, 10),
#  ('Sleepers', 'Stephen Hopkins', 18, 11),
#  ('Space Jam', 'Stephen Hopkins', 18, 12),
#  ("Stephen King's Thinner", 'Stephen Hopkins', 18, 13),
#  ('Michael Collins', 'Stephen Hopkins', 18, 14),
#  ('Romeo & Juliet', 'Stephen Hopkins', 18, 15),
#  ('Big Night', 'Stephen Hopkins', 18, 16),
#  ('Fly Away Home', 'Stephen Hopkins', 18, 17),
#  ('Nutty Professor, The', 'Stephen Hopkins', 18, 18),
#  ('Phenomenon', 'Stephen Hopkins', 18, 19),
#  ('Set It Off', 'Stephen Hopkins', 18, 20),
#  ('Surviving Picasso', 'Stephen Hopkins', 18, 21),
#  ('Very Brady Sequel, A', 'Stephen Hopkins', 18, 22),
#  ('That Thing You Do', 'Stephen Hopkins', 18, 23),
#  ('Associate, The', 'Bill Pullman', 19, 1),
#  ('Ghost & The Darkness, The', 'Bill Pullman', 19, 2),
#  ('Independence Day', 'Bill Pullman', 19, 3),
#  ('D3: The Mighty Ducks', 'Bill Pullman', 19, 4),
#  ('Dear God', 'Bill Pullman', 19, 5),
#  ('First Wives Club, The', 'Bill Pullman', 19, 6),
#  ('High School High', 'Bill Pullman', 19, 7),
#  ('Larger Than Life', 'Bill Pullman', 19, 8),
#  ('Mirror Has Two Faces, The', 'Bill Pullman', 19, 9),
#  ('Ransom', 'Bill Pullman', 19, 10),
#  ('Sleepers', 'Bill Pullman', 19, 11),
#  ('Space Jam', 'Bill Pullman', 19, 12),
#  ("Stephen King's Thinner", 'Bill Pullman', 19, 13),
#  ('Michael Collins', 'Bill Pullman', 19, 14),
#  ('Romeo & Juliet', 'Bill Pullman', 19, 15),
#  ('Big Night', 'Bill Pullman', 19, 16),
#  ('Fly Away Home', 'Bill Pullman', 19, 17),
#  ('Nutty Professor, The', 'Bill Pullman', 19, 18),
#  ('Phenomenon', 'Bill Pullman', 19, 19),
#  ('Set It Off', 'Bill Pullman', 19, 20),
#  ('Surviving Picasso', 'Bill Pullman', 19, 21),
#  ('Very Brady Sequel, A', 'Bill Pullman', 19, 22),
#  ('That Thing You Do', 'Bill Pullman', 19, 23),
#  ('Associate, The', 'Bill Smitrovich', 20, 1),
#  ('Ghost & The Darkness, The', 'Bill Smitrovich', 20, 2),
#  ('Independence Day', 'Bill Smitrovich', 20, 3),
#  ('D3: The Mighty Ducks', 'Bill Smitrovich', 20, 4),
#  ('Dear God', 'Bill Smitrovich', 20, 5),
#  ('First Wives Club, The', 'Bill Smitrovich', 20, 6),
#  ('High School High', 'Bill Smitrovich', 20, 7),
#  ('Larger Than Life', 'Bill Smitrovich', 20, 8),
#  ('Mirror Has Two Faces, The', 'Bill Smitrovich', 20, 9),
#  ('Ransom', 'Bill Smitrovich', 20, 10),
#  ('Sleepers', 'Bill Smitrovich', 20, 11),
#  ('Space Jam', 'Bill Smitrovich', 20, 12),
#  ("Stephen King's Thinner", 'Bill Smitrovich', 20, 13),
#  ('Michael Collins', 'Bill Smitrovich', 20, 14),
#  ('Romeo & Juliet', 'Bill Smitrovich', 20, 15),
#  ('Big Night', 'Bill Smitrovich', 20, 16),
#  ('Fly Away Home', 'Bill Smitrovich', 20, 17),
#  ('Nutty Professor, The', 'Bill Smitrovich', 20, 18),
#  ('Phenomenon', 'Bill Smitrovich', 20, 19),
#  ('Set It Off', 'Bill Smitrovich', 20, 20),
#  ('Surviving Picasso', 'Bill Smitrovich', 20, 21),
#  ('Very Brady Sequel, A', 'Bill Smitrovich', 20, 22),
#  ('That Thing You Do', 'Bill Smitrovich', 20, 23),
#  ('Associate, The', 'Harvey Fierstein', 21, 1),
#  ('Ghost & The Darkness, The', 'Harvey Fierstein', 21, 2),
#  ('Independence Day', 'Harvey Fierstein', 21, 3),
#  ('D3: The Mighty Ducks', 'Harvey Fierstein', 21, 4),
#  ('Dear God', 'Harvey Fierstein', 21, 5),
#  ('First Wives Club, The', 'Harvey Fierstein', 21, 6),
#  ('High School High', 'Harvey Fierstein', 21, 7),
#  ('Larger Than Life', 'Harvey Fierstein', 21, 8),
#  ('Mirror Has Two Faces, The', 'Harvey Fierstein', 21, 9),
#  ('Ransom', 'Harvey Fierstein', 21, 10),
#  ('Sleepers', 'Harvey Fierstein', 21, 11),
#  ('Space Jam', 'Harvey Fierstein', 21, 12),
#  ("Stephen King's Thinner", 'Harvey Fierstein', 21, 13),
#  ('Michael Collins', 'Harvey Fierstein', 21, 14),
#  ('Romeo & Juliet', 'Harvey Fierstein', 21, 15),
#  ('Big Night', 'Harvey Fierstein', 21, 16),
#  ('Fly Away Home', 'Harvey Fierstein', 21, 17),
#  ('Nutty Professor, The', 'Harvey Fierstein', 21, 18),
#  ('Phenomenon', 'Harvey Fierstein', 21, 19),
#  ('Set It Off', 'Harvey Fierstein', 21, 20),
#  ('Surviving Picasso', 'Harvey Fierstein', 21, 21),
#  ('Very Brady Sequel, A', 'Harvey Fierstein', 21, 22),
#  ('That Thing You Do', 'Harvey Fierstein', 21, 23),
#  ('Associate, The', 'Jeff Goldblum', 22, 1),
#  ('Ghost & The Darkness, The', 'Jeff Goldblum', 22, 2),
#  ('Independence Day', 'Jeff Goldblum', 22, 3),
#  ('D3: The Mighty Ducks', 'Jeff Goldblum', 22, 4),
#  ('Dear God', 'Jeff Goldblum', 22, 5),
#  ('First Wives Club, The', 'Jeff Goldblum', 22, 6),
#  ('High School High', 'Jeff Goldblum', 22, 7),
#  ('Larger Than Life', 'Jeff Goldblum', 22, 8),
#  ('Mirror Has Two Faces, The', 'Jeff Goldblum', 22, 9),
#  ('Ransom', 'Jeff Goldblum', 22, 10),
#  ('Sleepers', 'Jeff Goldblum', 22, 11),
#  ('Space Jam', 'Jeff Goldblum', 22, 12),
#  ("Stephen King's Thinner", 'Jeff Goldblum', 22, 13),
#  ('Michael Collins', 'Jeff Goldblum', 22, 14),
#  ('Romeo & Juliet', 'Jeff Goldblum', 22, 15),
#  ('Big Night', 'Jeff Goldblum', 22, 16),
#  ('Fly Away Home', 'Jeff Goldblum', 22, 17),
#  ('Nutty Professor, The', 'Jeff Goldblum', 22, 18),
#  ('Phenomenon', 'Jeff Goldblum', 22, 19),
#  ('Set It Off', 'Jeff Goldblum', 22, 20),
#  ('Surviving Picasso', 'Jeff Goldblum', 22, 21),
#  ('Very Brady Sequel, A', 'Jeff Goldblum', 22, 22),
#  ('That Thing You Do', 'Jeff Goldblum', 22, 23),
#  ('Associate, The', 'Judd Hirsch', 23, 1),
#  ('Ghost & The Darkness, The', 'Judd Hirsch', 23, 2),
#  ('Independence Day', 'Judd Hirsch', 23, 3),
#  ('D3: The Mighty Ducks', 'Judd Hirsch', 23, 4),
#  ('Dear God', 'Judd Hirsch', 23, 5),
#  ('First Wives Club, The', 'Judd Hirsch', 23, 6),
#  ('High School High', 'Judd Hirsch', 23, 7),
#  ('Larger Than Life', 'Judd Hirsch', 23, 8),
#  ('Mirror Has Two Faces, The', 'Judd Hirsch', 23, 9),
#  ('Ransom', 'Judd Hirsch', 23, 10),
#  ('Sleepers', 'Judd Hirsch', 23, 11),
#  ('Space Jam', 'Judd Hirsch', 23, 12),
#  ("Stephen King's Thinner", 'Judd Hirsch', 23, 13),
#  ('Michael Collins', 'Judd Hirsch', 23, 14),
#  ('Romeo & Juliet', 'Judd Hirsch', 23, 15),
#  ('Big Night', 'Judd Hirsch', 23, 16),
#  ('Fly Away Home', 'Judd Hirsch', 23, 17),
#  ('Nutty Professor, The', 'Judd Hirsch', 23, 18),
#  ('Phenomenon', 'Judd Hirsch', 23, 19),
#  ('Set It Off', 'Judd Hirsch', 23, 20),
#  ('Surviving Picasso', 'Judd Hirsch', 23, 21),
#  ('Very Brady Sequel, A', 'Judd Hirsch', 23, 22),
#  ('That Thing You Do', 'Judd Hirsch', 23, 23),
#  ('Associate, The', 'Margaret Colin', 24, 1),
#  ('Ghost & The Darkness, The', 'Margaret Colin', 24, 2),
#  ('Independence Day', 'Margaret Colin', 24, 3),
#  ('D3: The Mighty Ducks', 'Margaret Colin', 24, 4),
#  ('Dear God', 'Margaret Colin', 24, 5),
#  ('First Wives Club, The', 'Margaret Colin', 24, 6),
#  ('High School High', 'Margaret Colin', 24, 7),
#  ('Larger Than Life', 'Margaret Colin', 24, 8),
#  ('Mirror Has Two Faces, The', 'Margaret Colin', 24, 9),
#  ('Ransom', 'Margaret Colin', 24, 10),
#  ('Sleepers', 'Margaret Colin', 24, 11),
#  ('Space Jam', 'Margaret Colin', 24, 12),
#  ("Stephen King's Thinner", 'Margaret Colin', 24, 13),
#  ('Michael Collins', 'Margaret Colin', 24, 14),
#  ('Romeo & Juliet', 'Margaret Colin', 24, 15),
#  ('Big Night', 'Margaret Colin', 24, 16),
#  ('Fly Away Home', 'Margaret Colin', 24, 17),
#  ('Nutty Professor, The', 'Margaret Colin', 24, 18),
#  ('Phenomenon', 'Margaret Colin', 24, 19),
#  ('Set It Off', 'Margaret Colin', 24, 20),
#  ('Surviving Picasso', 'Margaret Colin', 24, 21),
#  ('Very Brady Sequel, A', 'Margaret Colin', 24, 22),
#  ('That Thing You Do', 'Margaret Colin', 24, 23),
#  ('Associate, The', 'Mary McDonnell', 25, 1),
#  ('Ghost & The Darkness, The', 'Mary McDonnell', 25, 2),
#  ('Independence Day', 'Mary McDonnell', 25, 3),
#  ('D3: The Mighty Ducks', 'Mary McDonnell', 25, 4),
#  ('Dear God', 'Mary McDonnell', 25, 5),
#  ('First Wives Club, The', 'Mary McDonnell', 25, 6),
#  ('High School High', 'Mary McDonnell', 25, 7),
#  ('Larger Than Life', 'Mary McDonnell', 25, 8),
#  ('Mirror Has Two Faces, The', 'Mary McDonnell', 25, 9),
#  ('Ransom', 'Mary McDonnell', 25, 10),
#  ('Sleepers', 'Mary McDonnell', 25, 11),
#  ('Space Jam', 'Mary McDonnell', 25, 12),
#  ("Stephen King's Thinner", 'Mary McDonnell', 25, 13),
#  ('Michael Collins', 'Mary McDonnell', 25, 14),
#  ('Romeo & Juliet', 'Mary McDonnell', 25, 15),
#  ('Big Night', 'Mary McDonnell', 25, 16),
#  ('Fly Away Home', 'Mary McDonnell', 25, 17),
#  ('Nutty Professor, The', 'Mary McDonnell', 25, 18),
#  ('Phenomenon', 'Mary McDonnell', 25, 19),
#  ('Set It Off', 'Mary McDonnell', 25, 20),
#  ('Surviving Picasso', 'Mary McDonnell', 25, 21),
#  ('Very Brady Sequel, A', 'Mary McDonnell', 25, 22),
#  ('That Thing You Do', 'Mary McDonnell', 25, 23),
#  ('Associate, The', 'Randy Quaid', 26, 1),
#  ('Ghost & The Darkness, The', 'Randy Quaid', 26, 2),
#  ('Independence Day', 'Randy Quaid', 26, 3),
#  ('D3: The Mighty Ducks', 'Randy Quaid', 26, 4),
#  ('Dear God', 'Randy Quaid', 26, 5),
#  ('First Wives Club, The', 'Randy Quaid', 26, 6),
#  ('High School High', 'Randy Quaid', 26, 7),
#  ('Larger Than Life', 'Randy Quaid', 26, 8),
#  ('Mirror Has Two Faces, The', 'Randy Quaid', 26, 9),
#  ('Ransom', 'Randy Quaid', 26, 10),
#  ('Sleepers', 'Randy Quaid', 26, 11),
#  ('Space Jam', 'Randy Quaid', 26, 12),
#  ("Stephen King's Thinner", 'Randy Quaid', 26, 13),
#  ('Michael Collins', 'Randy Quaid', 26, 14),
#  ('Romeo & Juliet', 'Randy Quaid', 26, 15),
#  ('Big Night', 'Randy Quaid', 26, 16),
#  ('Fly Away Home', 'Randy Quaid', 26, 17),
#  ('Nutty Professor, The', 'Randy Quaid', 26, 18),
#  ('Phenomenon', 'Randy Quaid', 26, 19),
#  ('Set It Off', 'Randy Quaid', 26, 20),
#  ('Surviving Picasso', 'Randy Quaid', 26, 21),
#  ('Very Brady Sequel, A', 'Randy Quaid', 26, 22),
#  ('That Thing You Do', 'Randy Quaid', 26, 23),
#  ('Associate, The', 'Robert Loggia', 27, 1),
#  ('Ghost & The Darkness, The', 'Robert Loggia', 27, 2),
#  ('Independence Day', 'Robert Loggia', 27, 3),
#  ('D3: The Mighty Ducks', 'Robert Loggia', 27, 4),
#  ('Dear God', 'Robert Loggia', 27, 5),
#  ('First Wives Club, The', 'Robert Loggia', 27, 6),
#  ('High School High', 'Robert Loggia', 27, 7),
#  ('Larger Than Life', 'Robert Loggia', 27, 8),
#  ('Mirror Has Two Faces, The', 'Robert Loggia', 27, 9),
#  ('Ransom', 'Robert Loggia', 27, 10),
#  ('Sleepers', 'Robert Loggia', 27, 11),
#  ('Space Jam', 'Robert Loggia', 27, 12),
#  ("Stephen King's Thinner", 'Robert Loggia', 27, 13),
#  ('Michael Collins', 'Robert Loggia', 27, 14),
#  ('Romeo & Juliet', 'Robert Loggia', 27, 15),
#  ('Big Night', 'Robert Loggia', 27, 16),
#  ('Fly Away Home', 'Robert Loggia', 27, 17),
#  ('Nutty Professor, The', 'Robert Loggia', 27, 18),
#  ('Phenomenon', 'Robert Loggia', 27, 19),
#  ('Set It Off', 'Robert Loggia', 27, 20),
#  ('Surviving Picasso', 'Robert Loggia', 27, 21),
#  ('Very Brady Sequel, A', 'Robert Loggia', 27, 22),
#  ('That Thing You Do', 'Robert Loggia', 27, 23),
#  ('Associate, The', 'Vivica Fox', 28, 1),
#  ('Ghost & The Darkness, The', 'Vivica Fox', 28, 2),
#  ('Independence Day', 'Vivica Fox', 28, 3),
#  ('D3: The Mighty Ducks', 'Vivica Fox', 28, 4),
#  ('Dear God', 'Vivica Fox', 28, 5),
#  ('First Wives Club, The', 'Vivica Fox', 28, 6),
#  ('High School High', 'Vivica Fox', 28, 7),
#  ('Larger Than Life', 'Vivica Fox', 28, 8),
#  ('Mirror Has Two Faces, The', 'Vivica Fox', 28, 9),
#  ('Ransom', 'Vivica Fox', 28, 10),
#  ('Sleepers', 'Vivica Fox', 28, 11),
#  ('Space Jam', 'Vivica Fox', 28, 12),
#  ("Stephen King's Thinner", 'Vivica Fox', 28, 13),
#  ('Michael Collins', 'Vivica Fox', 28, 14),
#  ('Romeo & Juliet', 'Vivica Fox', 28, 15),
#  ('Big Night', 'Vivica Fox', 28, 16),
#  ('Fly Away Home', 'Vivica Fox', 28, 17),
#  ('Nutty Professor, The', 'Vivica Fox', 28, 18),
#  ('Phenomenon', 'Vivica Fox', 28, 19),
#  ('Set It Off', 'Vivica Fox', 28, 20),
#  ('Surviving Picasso', 'Vivica Fox', 28, 21),
#  ('Very Brady Sequel, A', 'Vivica Fox', 28, 22),
#  ('That Thing You Do', 'Vivica Fox', 28, 23),
#  ('Associate, The', 'Will Smith', 29, 1),
#  ('Ghost & The Darkness, The', 'Will Smith', 29, 2),
#  ('Independence Day', 'Will Smith', 29, 3),
#  ('D3: The Mighty Ducks', 'Will Smith', 29, 4),
#  ('Dear God', 'Will Smith', 29, 5),
#  ('First Wives Club, The', 'Will Smith', 29, 6),
#  ('High School High', 'Will Smith', 29, 7),
#  ('Larger Than Life', 'Will Smith', 29, 8),
#  ('Mirror Has Two Faces, The', 'Will Smith', 29, 9),
#  ('Ransom', 'Will Smith', 29, 10),
#  ('Sleepers', 'Will Smith', 29, 11),
#  ('Space Jam', 'Will Smith', 29, 12),
#  ("Stephen King's Thinner", 'Will Smith', 29, 13),
#  ('Michael Collins', 'Will Smith', 29, 14),
#  ('Romeo & Juliet', 'Will Smith', 29, 15),
#  ('Big Night', 'Will Smith', 29, 16),
#  ('Fly Away Home', 'Will Smith', 29, 17),
#  ('Nutty Professor, The', 'Will Smith', 29, 18),
#  ('Phenomenon', 'Will Smith', 29, 19),
#  ('Set It Off', 'Will Smith', 29, 20),
#  ('Surviving Picasso', 'Will Smith', 29, 21),
#  ('Very Brady Sequel, A', 'Will Smith', 29, 22),
#  ('That Thing You Do', 'Will Smith', 29, 23),
#  ('Associate, The', 'Roland Emmerich', 30, 1),
#  ('Ghost & The Darkness, The', 'Roland Emmerich', 30, 2),
#  ('Independence Day', 'Roland Emmerich', 30, 3),
#  ('D3: The Mighty Ducks', 'Roland Emmerich', 30, 4),
#  ('Dear God', 'Roland Emmerich', 30, 5),
#  ('First Wives Club, The', 'Roland Emmerich', 30, 6),
#  ('High School High', 'Roland Emmerich', 30, 7),
#  ('Larger Than Life', 'Roland Emmerich', 30, 8),
#  ('Mirror Has Two Faces, The', 'Roland Emmerich', 30, 9),
#  ('Ransom', 'Roland Emmerich', 30, 10),
#  ('Sleepers', 'Roland Emmerich', 30, 11),
#  ('Space Jam', 'Roland Emmerich', 30, 12),
#  ("Stephen King's Thinner", 'Roland Emmerich', 30, 13),
#  ('Michael Collins', 'Roland Emmerich', 30, 14),
#  ('Romeo & Juliet', 'Roland Emmerich', 30, 15),
#  ('Big Night', 'Roland Emmerich', 30, 16),
#  ('Fly Away Home', 'Roland Emmerich', 30, 17),
#  ('Nutty Professor, The', 'Roland Emmerich', 30, 18),
#  ('Phenomenon', 'Roland Emmerich', 30, 19),
#  ('Set It Off', 'Roland Emmerich', 30, 20),
#  ('Surviving Picasso', 'Roland Emmerich', 30, 21),
#  ('Very Brady Sequel, A', 'Roland Emmerich', 30, 22),
#  ('That Thing You Do', 'Roland Emmerich', 30, 23),
#  ('Associate, The', 'Emilio Estevez', 31, 1),
#  ('Ghost & The Darkness, The', 'Emilio Estevez', 31, 2),
#  ('Independence Day', 'Emilio Estevez', 31, 3),
#  ('D3: The Mighty Ducks', 'Emilio Estevez', 31, 4),
#  ('Dear God', 'Emilio Estevez', 31, 5),
#  ('First Wives Club, The', 'Emilio Estevez', 31, 6),
#  ('High School High', 'Emilio Estevez', 31, 7),
#  ('Larger Than Life', 'Emilio Estevez', 31, 8),
#  ('Mirror Has Two Faces, The', 'Emilio Estevez', 31, 9),
#  ('Ransom', 'Emilio Estevez', 31, 10),
#  ('Sleepers', 'Emilio Estevez', 31, 11),
#  ('Space Jam', 'Emilio Estevez', 31, 12),
#  ("Stephen King's Thinner", 'Emilio Estevez', 31, 13),
#  ('Michael Collins', 'Emilio Estevez', 31, 14),
#  ('Romeo & Juliet', 'Emilio Estevez', 31, 15),
#  ('Big Night', 'Emilio Estevez', 31, 16),
#  ('Fly Away Home', 'Emilio Estevez', 31, 17),
#  ('Nutty Professor, The', 'Emilio Estevez', 31, 18),
#  ('Phenomenon', 'Emilio Estevez', 31, 19),
#  ('Set It Off', 'Emilio Estevez', 31, 20),
#  ('Surviving Picasso', 'Emilio Estevez', 31, 21),
#  ('Very Brady Sequel, A', 'Emilio Estevez', 31, 22),
#  ('That Thing You Do', 'Emilio Estevez', 31, 23),
#  ('Associate, The', 'Heidi Kling', 32, 1),
#  ('Ghost & The Darkness, The', 'Heidi Kling', 32, 2),
#  ('Independence Day', 'Heidi Kling', 32, 3),
#  ('D3: The Mighty Ducks', 'Heidi Kling', 32, 4),
#  ('Dear God', 'Heidi Kling', 32, 5),
#  ('First Wives Club, The', 'Heidi Kling', 32, 6),
#  ('High School High', 'Heidi Kling', 32, 7),
#  ('Larger Than Life', 'Heidi Kling', 32, 8),
#  ('Mirror Has Two Faces, The', 'Heidi Kling', 32, 9),
#  ('Ransom', 'Heidi Kling', 32, 10),
#  ('Sleepers', 'Heidi Kling', 32, 11),
#  ('Space Jam', 'Heidi Kling', 32, 12),
#  ("Stephen King's Thinner", 'Heidi Kling', 32, 13),
#  ('Michael Collins', 'Heidi Kling', 32, 14),
#  ('Romeo & Juliet', 'Heidi Kling', 32, 15),
#  ('Big Night', 'Heidi Kling', 32, 16),
#  ('Fly Away Home', 'Heidi Kling', 32, 17),
#  ('Nutty Professor, The', 'Heidi Kling', 32, 18),
#  ('Phenomenon', 'Heidi Kling', 32, 19),
#  ('Set It Off', 'Heidi Kling', 32, 20),
#  ('Surviving Picasso', 'Heidi Kling', 32, 21),
#  ('Very Brady Sequel, A', 'Heidi Kling', 32, 22),
#  ('That Thing You Do', 'Heidi Kling', 32, 23),
#  ('Associate, The', 'Jeffrey Nordling', 33, 1),
#  ('Ghost & The Darkness, The', 'Jeffrey Nordling', 33, 2),
#  ('Independence Day', 'Jeffrey Nordling', 33, 3),
#  ('D3: The Mighty Ducks', 'Jeffrey Nordling', 33, 4),
#  ('Dear God', 'Jeffrey Nordling', 33, 5),
#  ('First Wives Club, The', 'Jeffrey Nordling', 33, 6),
#  ('High School High', 'Jeffrey Nordling', 33, 7),
#  ('Larger Than Life', 'Jeffrey Nordling', 33, 8),
#  ('Mirror Has Two Faces, The', 'Jeffrey Nordling', 33, 9),
#  ('Ransom', 'Jeffrey Nordling', 33, 10),
#  ('Sleepers', 'Jeffrey Nordling', 33, 11),
#  ('Space Jam', 'Jeffrey Nordling', 33, 12),
#  ("Stephen King's Thinner", 'Jeffrey Nordling', 33, 13),
#  ('Michael Collins', 'Jeffrey Nordling', 33, 14),
#  ('Romeo & Juliet', 'Jeffrey Nordling', 33, 15),
#  ('Big Night', 'Jeffrey Nordling', 33, 16),
#  ('Fly Away Home', 'Jeffrey Nordling', 33, 17),
#  ('Nutty Professor, The', 'Jeffrey Nordling', 33, 18),
#  ('Phenomenon', 'Jeffrey Nordling', 33, 19),
#  ('Set It Off', 'Jeffrey Nordling', 33, 20),
#  ('Surviving Picasso', 'Jeffrey Nordling', 33, 21),
#  ('Very Brady Sequel, A', 'Jeffrey Nordling', 33, 22),
#  ('That Thing You Do', 'Jeffrey Nordling', 33, 23),
#  ('Associate, The', 'Joss Ackland', 34, 1),
#  ('Ghost & The Darkness, The', 'Joss Ackland', 34, 2),
#  ('Independence Day', 'Joss Ackland', 34, 3),
#  ('D3: The Mighty Ducks', 'Joss Ackland', 34, 4),
#  ('Dear God', 'Joss Ackland', 34, 5),
#  ('First Wives Club, The', 'Joss Ackland', 34, 6),
#  ('High School High', 'Joss Ackland', 34, 7),
#  ('Larger Than Life', 'Joss Ackland', 34, 8),
#  ('Mirror Has Two Faces, The', 'Joss Ackland', 34, 9),
#  ('Ransom', 'Joss Ackland', 34, 10),
#  ('Sleepers', 'Joss Ackland', 34, 11),
#  ('Space Jam', 'Joss Ackland', 34, 12),
#  ("Stephen King's Thinner", 'Joss Ackland', 34, 13),
#  ('Michael Collins', 'Joss Ackland', 34, 14),
#  ('Romeo & Juliet', 'Joss Ackland', 34, 15),
#  ('Big Night', 'Joss Ackland', 34, 16),
#  ('Fly Away Home', 'Joss Ackland', 34, 17),
#  ('Nutty Professor, The', 'Joss Ackland', 34, 18),
#  ('Phenomenon', 'Joss Ackland', 34, 19),
#  ('Set It Off', 'Joss Ackland', 34, 20),
#  ('Surviving Picasso', 'Joss Ackland', 34, 21),
#  ('Very Brady Sequel, A', 'Joss Ackland', 34, 22),
#  ('That Thing You Do', 'Joss Ackland', 34, 23),
#  ('Associate, The', 'Rob Lieberman', 35, 1),
#  ('Ghost & The Darkness, The', 'Rob Lieberman', 35, 2),
#  ('Independence Day', 'Rob Lieberman', 35, 3),
#  ('D3: The Mighty Ducks', 'Rob Lieberman', 35, 4),
#  ('Dear God', 'Rob Lieberman', 35, 5),
#  ('First Wives Club, The', 'Rob Lieberman', 35, 6),
#  ('High School High', 'Rob Lieberman', 35, 7),
#  ('Larger Than Life', 'Rob Lieberman', 35, 8),
#  ('Mirror Has Two Faces, The', 'Rob Lieberman', 35, 9),
#  ('Ransom', 'Rob Lieberman', 35, 10),
#  ('Sleepers', 'Rob Lieberman', 35, 11),
#  ('Space Jam', 'Rob Lieberman', 35, 12),
#  ("Stephen King's Thinner", 'Rob Lieberman', 35, 13),
#  ('Michael Collins', 'Rob Lieberman', 35, 14),
#  ('Romeo & Juliet', 'Rob Lieberman', 35, 15),
#  ('Big Night', 'Rob Lieberman', 35, 16),
#  ('Fly Away Home', 'Rob Lieberman', 35, 17),
#  ('Nutty Professor, The', 'Rob Lieberman', 35, 18),
#  ('Phenomenon', 'Rob Lieberman', 35, 19),
#  ('Set It Off', 'Rob Lieberman', 35, 20),
#  ('Surviving Picasso', 'Rob Lieberman', 35, 21),
#  ('Very Brady Sequel, A', 'Rob Lieberman', 35, 22),
#  ('That Thing You Do', 'Rob Lieberman', 35, 23),
#  ('Associate, The', 'Greg Kinnear', 36, 1),
#  ('Ghost & The Darkness, The', 'Greg Kinnear', 36, 2),
#  ('Independence Day', 'Greg Kinnear', 36, 3),
#  ('D3: The Mighty Ducks', 'Greg Kinnear', 36, 4),
#  ('Dear God', 'Greg Kinnear', 36, 5),
#  ('First Wives Club, The', 'Greg Kinnear', 36, 6),
#  ('High School High', 'Greg Kinnear', 36, 7),
#  ('Larger Than Life', 'Greg Kinnear', 36, 8),
#  ('Mirror Has Two Faces, The', 'Greg Kinnear', 36, 9),
#  ('Ransom', 'Greg Kinnear', 36, 10),
#  ('Sleepers', 'Greg Kinnear', 36, 11),
#  ('Space Jam', 'Greg Kinnear', 36, 12),
#  ("Stephen King's Thinner", 'Greg Kinnear', 36, 13),
#  ('Michael Collins', 'Greg Kinnear', 36, 14),
#  ('Romeo & Juliet', 'Greg Kinnear', 36, 15),
#  ('Big Night', 'Greg Kinnear', 36, 16),
#  ('Fly Away Home', 'Greg Kinnear', 36, 17),
#  ('Nutty Professor, The', 'Greg Kinnear', 36, 18),
#  ('Phenomenon', 'Greg Kinnear', 36, 19),
#  ('Set It Off', 'Greg Kinnear', 36, 20),
#  ('Surviving Picasso', 'Greg Kinnear', 36, 21),
#  ('Very Brady Sequel, A', 'Greg Kinnear', 36, 22),
#  ('That Thing You Do', 'Greg Kinnear', 36, 23),
#  ('Associate, The', 'Hector Elizondo', 37, 1),
#  ('Ghost & The Darkness, The', 'Hector Elizondo', 37, 2),
#  ('Independence Day', 'Hector Elizondo', 37, 3),
#  ('D3: The Mighty Ducks', 'Hector Elizondo', 37, 4),
#  ('Dear God', 'Hector Elizondo', 37, 5),
#  ('First Wives Club, The', 'Hector Elizondo', 37, 6),
#  ('High School High', 'Hector Elizondo', 37, 7),
#  ('Larger Than Life', 'Hector Elizondo', 37, 8),
#  ('Mirror Has Two Faces, The', 'Hector Elizondo', 37, 9),
#  ('Ransom', 'Hector Elizondo', 37, 10),
#  ('Sleepers', 'Hector Elizondo', 37, 11),
#  ('Space Jam', 'Hector Elizondo', 37, 12),
#  ("Stephen King's Thinner", 'Hector Elizondo', 37, 13),
#  ('Michael Collins', 'Hector Elizondo', 37, 14),
#  ('Romeo & Juliet', 'Hector Elizondo', 37, 15),
#  ('Big Night', 'Hector Elizondo', 37, 16),
#  ('Fly Away Home', 'Hector Elizondo', 37, 17),
#  ('Nutty Professor, The', 'Hector Elizondo', 37, 18),
#  ('Phenomenon', 'Hector Elizondo', 37, 19),
#  ('Set It Off', 'Hector Elizondo', 37, 20),
#  ('Surviving Picasso', 'Hector Elizondo', 37, 21),
#  ('Very Brady Sequel, A', 'Hector Elizondo', 37, 22),
#  ('That Thing You Do', 'Hector Elizondo', 37, 23),
#  ('Associate, The', 'Jon Seda', 38, 1),
#  ('Ghost & The Darkness, The', 'Jon Seda', 38, 2),
#  ('Independence Day', 'Jon Seda', 38, 3),
#  ('D3: The Mighty Ducks', 'Jon Seda', 38, 4),
#  ('Dear God', 'Jon Seda', 38, 5),
#  ('First Wives Club, The', 'Jon Seda', 38, 6),
#  ('High School High', 'Jon Seda', 38, 7),
#  ('Larger Than Life', 'Jon Seda', 38, 8),
#  ('Mirror Has Two Faces, The', 'Jon Seda', 38, 9),
#  ('Ransom', 'Jon Seda', 38, 10),
#  ('Sleepers', 'Jon Seda', 38, 11),
#  ('Space Jam', 'Jon Seda', 38, 12),
#  ("Stephen King's Thinner", 'Jon Seda', 38, 13),
#  ('Michael Collins', 'Jon Seda', 38, 14),
#  ('Romeo & Juliet', 'Jon Seda', 38, 15),
#  ('Big Night', 'Jon Seda', 38, 16),
#  ('Fly Away Home', 'Jon Seda', 38, 17),
#  ('Nutty Professor, The', 'Jon Seda', 38, 18),
#  ('Phenomenon', 'Jon Seda', 38, 19),
#  ('Set It Off', 'Jon Seda', 38, 20),
#  ('Surviving Picasso', 'Jon Seda', 38, 21),
#  ('Very Brady Sequel, A', 'Jon Seda', 38, 22),
#  ('That Thing You Do', 'Jon Seda', 38, 23),
#  ('Associate, The', 'Laurie Metcalf', 39, 1),
#  ('Ghost & The Darkness, The', 'Laurie Metcalf', 39, 2),
#  ('Independence Day', 'Laurie Metcalf', 39, 3),
#  ('D3: The Mighty Ducks', 'Laurie Metcalf', 39, 4),
#  ('Dear God', 'Laurie Metcalf', 39, 5),
#  ('First Wives Club, The', 'Laurie Metcalf', 39, 6),
#  ('High School High', 'Laurie Metcalf', 39, 7),
#  ('Larger Than Life', 'Laurie Metcalf', 39, 8),
#  ('Mirror Has Two Faces, The', 'Laurie Metcalf', 39, 9),
#  ('Ransom', 'Laurie Metcalf', 39, 10),
#  ('Sleepers', 'Laurie Metcalf', 39, 11),
#  ('Space Jam', 'Laurie Metcalf', 39, 12),
#  ("Stephen King's Thinner", 'Laurie Metcalf', 39, 13),
#  ('Michael Collins', 'Laurie Metcalf', 39, 14),
#  ('Romeo & Juliet', 'Laurie Metcalf', 39, 15),
#  ('Big Night', 'Laurie Metcalf', 39, 16),
#  ('Fly Away Home', 'Laurie Metcalf', 39, 17),
#  ('Nutty Professor, The', 'Laurie Metcalf', 39, 18),
#  ('Phenomenon', 'Laurie Metcalf', 39, 19),
#  ('Set It Off', 'Laurie Metcalf', 39, 20),
#  ('Surviving Picasso', 'Laurie Metcalf', 39, 21),
#  ('Very Brady Sequel, A', 'Laurie Metcalf', 39, 22),
#  ('That Thing You Do', 'Laurie Metcalf', 39, 23),
#  ('Associate, The', 'Maria Pitillo', 40, 1),
#  ('Ghost & The Darkness, The', 'Maria Pitillo', 40, 2),
#  ('Independence Day', 'Maria Pitillo', 40, 3),
#  ('D3: The Mighty Ducks', 'Maria Pitillo', 40, 4),
#  ('Dear God', 'Maria Pitillo', 40, 5),
#  ('First Wives Club, The', 'Maria Pitillo', 40, 6),
#  ('High School High', 'Maria Pitillo', 40, 7),
#  ('Larger Than Life', 'Maria Pitillo', 40, 8),
#  ('Mirror Has Two Faces, The', 'Maria Pitillo', 40, 9),
#  ('Ransom', 'Maria Pitillo', 40, 10),
#  ('Sleepers', 'Maria Pitillo', 40, 11),
#  ('Space Jam', 'Maria Pitillo', 40, 12),
#  ("Stephen King's Thinner", 'Maria Pitillo', 40, 13),
#  ('Michael Collins', 'Maria Pitillo', 40, 14),
#  ('Romeo & Juliet', 'Maria Pitillo', 40, 15),
#  ('Big Night', 'Maria Pitillo', 40, 16),
#  ('Fly Away Home', 'Maria Pitillo', 40, 17),
#  ('Nutty Professor, The', 'Maria Pitillo', 40, 18),
#  ('Phenomenon', 'Maria Pitillo', 40, 19),
#  ('Set It Off', 'Maria Pitillo', 40, 20),
#  ('Surviving Picasso', 'Maria Pitillo', 40, 21),
#  ('Very Brady Sequel, A', 'Maria Pitillo', 40, 22),
#  ('That Thing You Do', 'Maria Pitillo', 40, 23),
#  ('Associate, The', 'Roscoe Lee Browne', 41, 1),
#  ('Ghost & The Darkness, The', 'Roscoe Lee Browne', 41, 2),
#  ('Independence Day', 'Roscoe Lee Browne', 41, 3),
#  ('D3: The Mighty Ducks', 'Roscoe Lee Browne', 41, 4),
#  ('Dear God', 'Roscoe Lee Browne', 41, 5),
#  ('First Wives Club, The', 'Roscoe Lee Browne', 41, 6),
#  ('High School High', 'Roscoe Lee Browne', 41, 7),
#  ('Larger Than Life', 'Roscoe Lee Browne', 41, 8),
#  ('Mirror Has Two Faces, The', 'Roscoe Lee Browne', 41, 9),
#  ('Ransom', 'Roscoe Lee Browne', 41, 10),
#  ('Sleepers', 'Roscoe Lee Browne', 41, 11),
#  ('Space Jam', 'Roscoe Lee Browne', 41, 12),
#  ("Stephen King's Thinner", 'Roscoe Lee Browne', 41, 13),
#  ('Michael Collins', 'Roscoe Lee Browne', 41, 14),
#  ('Romeo & Juliet', 'Roscoe Lee Browne', 41, 15),
#  ('Big Night', 'Roscoe Lee Browne', 41, 16),
#  ('Fly Away Home', 'Roscoe Lee Browne', 41, 17),
#  ('Nutty Professor, The', 'Roscoe Lee Browne', 41, 18),
#  ('Phenomenon', 'Roscoe Lee Browne', 41, 19),
#  ('Set It Off', 'Roscoe Lee Browne', 41, 20),
#  ('Surviving Picasso', 'Roscoe Lee Browne', 41, 21),
#  ('Very Brady Sequel, A', 'Roscoe Lee Browne', 41, 22),
#  ('That Thing You Do', 'Roscoe Lee Browne', 41, 23),
#  ('Associate, The', 'Tim Conway', 42, 1),
#  ('Ghost & The Darkness, The', 'Tim Conway', 42, 2),
#  ('Independence Day', 'Tim Conway', 42, 3),
#  ('D3: The Mighty Ducks', 'Tim Conway', 42, 4),
#  ('Dear God', 'Tim Conway', 42, 5),
#  ('First Wives Club, The', 'Tim Conway', 42, 6),
#  ('High School High', 'Tim Conway', 42, 7),
#  ('Larger Than Life', 'Tim Conway', 42, 8),
#  ('Mirror Has Two Faces, The', 'Tim Conway', 42, 9),
#  ('Ransom', 'Tim Conway', 42, 10),
#  ('Sleepers', 'Tim Conway', 42, 11),
#  ('Space Jam', 'Tim Conway', 42, 12),
#  ("Stephen King's Thinner", 'Tim Conway', 42, 13),
#  ('Michael Collins', 'Tim Conway', 42, 14),
#  ('Romeo & Juliet', 'Tim Conway', 42, 15),
#  ('Big Night', 'Tim Conway', 42, 16),
#  ('Fly Away Home', 'Tim Conway', 42, 17),
#  ('Nutty Professor, The', 'Tim Conway', 42, 18),
#  ('Phenomenon', 'Tim Conway', 42, 19),
#  ('Set It Off', 'Tim Conway', 42, 20),
#  ('Surviving Picasso', 'Tim Conway', 42, 21),
#  ('Very Brady Sequel, A', 'Tim Conway', 42, 22),
#  ('That Thing You Do', 'Tim Conway', 42, 23),
#  ('Associate, The', 'Garry Marshall', 43, 1),
#  ('Ghost & The Darkness, The', 'Garry Marshall', 43, 2),
#  ('Independence Day', 'Garry Marshall', 43, 3),
#  ('D3: The Mighty Ducks', 'Garry Marshall', 43, 4),
#  ('Dear God', 'Garry Marshall', 43, 5),
#  ('First Wives Club, The', 'Garry Marshall', 43, 6),
#  ('High School High', 'Garry Marshall', 43, 7),
#  ('Larger Than Life', 'Garry Marshall', 43, 8),
#  ('Mirror Has Two Faces, The', 'Garry Marshall', 43, 9),
#  ('Ransom', 'Garry Marshall', 43, 10),
#  ('Sleepers', 'Garry Marshall', 43, 11),
#  ('Space Jam', 'Garry Marshall', 43, 12),
#  ("Stephen King's Thinner", 'Garry Marshall', 43, 13),
#  ('Michael Collins', 'Garry Marshall', 43, 14),
#  ('Romeo & Juliet', 'Garry Marshall', 43, 15),
#  ('Big Night', 'Garry Marshall', 43, 16),
#  ('Fly Away Home', 'Garry Marshall', 43, 17),
#  ('Nutty Professor, The', 'Garry Marshall', 43, 18),
#  ('Phenomenon', 'Garry Marshall', 43, 19),
#  ('Set It Off', 'Garry Marshall', 43, 20),
#  ('Surviving Picasso', 'Garry Marshall', 43, 21),
#  ('Very Brady Sequel, A', 'Garry Marshall', 43, 22),
#  ('That Thing You Do', 'Garry Marshall', 43, 23),
#  ('Associate, The', 'Bette Midler', 44, 1),
#  ('Ghost & The Darkness, The', 'Bette Midler', 44, 2),
#  ('Independence Day', 'Bette Midler', 44, 3),
#  ('D3: The Mighty Ducks', 'Bette Midler', 44, 4),
#  ('Dear God', 'Bette Midler', 44, 5),
#  ('First Wives Club, The', 'Bette Midler', 44, 6),
#  ('High School High', 'Bette Midler', 44, 7),
#  ('Larger Than Life', 'Bette Midler', 44, 8),
#  ('Mirror Has Two Faces, The', 'Bette Midler', 44, 9),
#  ('Ransom', 'Bette Midler', 44, 10),
#  ('Sleepers', 'Bette Midler', 44, 11),
#  ...]

# %% [markdown]
# **4. Write a select query to display the number of distinct movies that each actor appears in.** The query should return the ActorName, MovieCount, and AID. You will need to use use a GROUP BY clause and the COUNT() function.

# %%
# %%sql
# SELECT DISTINCT A.Name, A.AID, Count(m.MID) AS MID
# FROM Movies m, Artist A, Credits c
# WHERE c.moviesID = m.MID AND c.ARTISTID = A.AID
# GROUP BY A.Name, A.AID
# Out:
# 152 rows affected.
# [('Aidan Quinn', 93, 1),
#  ('Alan Rickman', 94, 1),
#  ('Anna Paquin', 111, 1),
#  ('Anthony Hopkins', 132, 1),
#  ('Arlene Sanford', 147, 1),
#  ('Austin Pendleton', 1, 1),
#  ('Barbra Streisand', 60, 2),
#  ('Barry Levinson', 82, 1),
#  ('Baz Luhrmann', 105, 1),
#  ('Bebe Neuwirth', 2, 1),
#  ('Bernard Hill', 10, 1),
#  ('Bette Midler', 44, 1),
#  ('Bill Murray', 53, 2),
#  ('Bill Pullman', 19, 1),
#  ('Bill Smitrovich', 20, 1),
#  ('Billy Crudup', 70, 1),
#  ('Blair Underwood', 127, 1),
#  ('Brad Pitt', 71, 1),
#  ('Brad Renfro', 72, 1),
#  ('Brian McCardie', 11, 1),
#  ('Campbell Scott', 106, 2),
#  ('Carroll Ballard', 114, 1),
#  ('Christine Taylor', 137, 1),
#  ('Christopher Daniel Barnes', 138, 1),
#  ('Claire Danes', 99, 1),
#  ('Dana Delany', 112, 1),
#  ('Dave Chappelle', 115, 1),
#  ('Delroy Lindo', 64, 1),
#  ('Diane Keaton', 45, 1),
#  ('Diane Venora', 100, 2),
#  ('Dianne Wiest', 3, 1),
#  ('Donald Petrie', 9, 1),
#  ('Dustin Hoffman', 73, 1),
#  ('Eddie Murphy', 116, 1),
#  ('Eli Wallach', 4, 1),
#  ('Emilio Estevez', 31, 1),
#  ('Emily Mortimer', 12, 1),
#  ('Ethan Embry', 148, 1),
#  ('F. Gary Gray', 131, 1),
#  ('Forest Whitaker', 122, 1),
#  ('Garry Marshall', 43, 1),
#  ('Gary Cole', 139, 1),
#  ('Gary Sinese', 65, 1),
#  ('Goldie Hawn', 46, 1),
#  ('Greg Kinnear', 36, 1),
#  ('Hart Bochner', 52, 1),
#  ('Harvey Fierstein', 21, 1),
#  ('Hector Elizondo', 37, 1),
#  ('Heidi Kling', 32, 1),
#  ('Henriette Mantel', 140, 1),
#  ('Henry Cele', 13, 1),
#  ('Howard Franklin', 59, 1),
#  ('Hugh Wilson', 47, 1),
#  ('Ian Holm', 107, 1),
#  ('Isabella Rossellini', 108, 1),
#  ('Jada Pinkett', 117, 2),
#  ('James Coburn', 118, 1),
#  ('James Ivory', 136, 1),
#  ('Janeane Garofalo', 54, 1),
#  ('Jason Patric', 74, 1),
#  ('Jeff Bridges', 61, 1),
#  ('Jeff Daniels', 113, 1),
#  ('Jeff Goldblum', 22, 1),
#  ('Jeffrey Nordling', 33, 1),
#  ('Jennifer Elise Cox', 141, 1),
#  ('Jeremy Piven', 55, 1),
#  ('Jesse Lee', 142, 1),
#  ('Joan Plowright', 133, 1),
#  ('Joe Mantegna', 87, 1),
#  ('Joe Pytka', 86, 1),
#  ('John Ales', 119, 1),
#  ('John C. McGinley', 128, 1),
#  ('John Kani', 14, 1),
#  ('John Leguizamo', 101, 1),
#  ('John Travolta', 123, 1),
#  ('Johnathon Schaech', 149, 1),
#  ('Jon Lovitz', 49, 1),
#  ('Jon Seda', 38, 1),
#  ('Jon Turteltaub', 126, 1),
#  ('Joseph Perrino', 75, 1),
#  ('Joss Ackland', 34, 1),
#  ('Judd Hirsch', 23, 1),
#  ('Julia Roberts', 95, 1),
#  ('Julianne Moore', 134, 1),
#  ('Kari Wuhrer', 88, 1),
#  ('Keith David', 56, 1),
#  ('Kenny Kerr', 5, 1),
#  ('Kevin Bacon', 76, 1),
#  ('Kimberly Elise', 129, 1),
#  ('Kyra Sedgwick', 124, 1),
#  ('Lainie Kazan', 6, 1),
#  ('Larry Miller', 120, 1),
#  ('Lauren Bacall', 62, 1),
#  ('Laurie Metcalf', 39, 1),
#  ('Leonardo DiCaprio', 102, 1),
#  ('Liam Neeson', 96, 1),
#  ('Lili Taylor', 66, 1),
#  ('Louise Fletcher', 48, 1),
#  ('Lucinda Jenney', 89, 1),
#  ('Margaret Colin', 24, 1),
#  ('Maria Pitillo', 40, 1),
#  ('Mary McDonnell', 25, 1),
#  ('Matthew McConaughey', 57, 1),
#  ('Mekhi Phifer', 50, 1),
#  ('Mel Gibson', 67, 1),
#  ('Michael Constantine', 90, 1),
#  ('Michael Douglas', 15, 1),
#  ('Michael Jordan', 83, 1),
#  ('Minnie Driver', 77, 2),
#  ('Natascha McElhone', 135, 1),
#  ('Neil Jordan', 98, 1),
#  ('Olivia Hack', 143, 1),
#  ('Pat Hingle', 58, 1),
#  ('Paul Rudd', 103, 1),
#  ('Paul Sorvino', 104, 1),
#  ('Paul Sutera', 144, 1),
#  ('Pierce Brosnan', 63, 1),
#  ('Queen Latifah', 130, 1),
#  ('Randy Quaid', 26, 1),
#  ('Rene Russo', 68, 1),
#  ('Rob Lieberman', 35, 2),
#  ('Robert De Niro', 78, 1),
#  ('Robert Duvall', 125, 1),
#  ('Robert John Burke', 91, 1),
#  ('Robert Loggia', 27, 1),
#  ('Roland Emmerich', 30, 1),
#  ('Ron Eldard', 79, 1),
#  ('Ron Howard', 69, 1),
#  ('Roscoe Lee Browne', 41, 1),
#  ('Shelley Long', 145, 1),
#  ('Stanley Tucci', 109, 2),
#  ('Stephen Hopkins', 18, 1),
#  ('Stephen Rea', 97, 1),
#  ('Steve Zahn', 150, 1),
#  ('Terry Kinney', 80, 1),
#  ('Theresa Randle', 84, 1),
#  ('Tia Carrera', 51, 1),
#  ('Tim Conway', 42, 1),
#  ('Tim Daly', 7, 1),
#  ('Tim Matheson', 146, 1),
#  ('Tom Everett Scott', 151, 1),
#  ('Tom Hanks', 152, 1),
#  ('Tom Holland', 92, 1),
#  ('Tom Shadyac', 121, 1),
#  ('Tom Wilkinson', 16, 1),
#  ('Tony Shalhoub', 110, 1),
#  ('Val Kilmer', 17, 1),
#  ('Vittorio Gassman', 81, 1),
#  ('Vivica Fox', 28, 2),
#  ('Wayne Knight', 85, 1),
#  ('Whoopi Goldberg', 8, 1),
#  ('Will Smith', 29, 1)]

# %% [markdown]
# **5. Write a select query to display only the actors that appear in multiple movies.** The query should return the Actor Name, Movie Count, and AID. You can use the previous select query as a starting point. You will need to add a HAVING clause to do the restriction.

# %%
# %%sql
# SELECT DISTINCT A.Name, A.AID, Count(m.MID) AS MID
# FROM Movies m, Artist A, Credits c
# WHERE c.moviesID = m.MID AND c.ARTISTID = A.AID
# GROUP BY A.Name, A.AID
# HAVING COUNT(m.MID) > 1;
# Out:
# 9 rows affected.
# [('Barbra Streisand', 60, 2),
#  ('Bill Murray', 53, 2),
#  ('Campbell Scott', 106, 2),
#  ('Diane Venora', 100, 2),
#  ('Jada Pinkett', 117, 2),
#  ('Minnie Driver', 77, 2),
#  ('Rob Lieberman', 35, 2),
#  ('Stanley Tucci', 109, 2),
#  ('Vivica Fox', 28, 2)]

# %% [markdown]
# **6. Write a select query to display directors that also act in their movies.** The query should return the ArtistName, NumDirectorCredits, NumActorCredits, NumDirectorActorCredits. Each count should be calculated separately using a subquery. Note: NumDirectorActorCredits should be greater than 0.
